# %% [markdown]
# <a href="https://colab.research.google.com/github/IsabelZaldivarG/silver-garbanzo/blob/main/00_Glosario_(Python).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Glosario
#
# 1. División entera (//)
#
# >Es una división entre dos números cuyo resultado es siempre entero, redondeandose hacia abajo.
#
# 2. Expresiones
#
# >Es una combinación de operadores y números.
#
# 3. Valor
#
# >Es el resultado de una expresión
#
# 4. Error: SynthaxError
#
# >Ocurre cuando llamo una función y cometo un error en su escritura (por ejemplo abs 42, esta es un error pues faltan los parentesis)
#
# 5. Función len
#
# >Muestra la cantidad de caracteres en un string.
#
# 6. Error: TypeError
#
# >En texto solo se pueden realizar las operaciones matematicas de + y *, las otras terminaran en TypeError.
#
# 7. Debugging
#
# 8. Keyworld
#
# >Son palabras que sirven para realizar cosas en python, ej: if, class, True. No pueden ser utilizados como nombre de variable.
#
# 9. Int
# Int puede tomar un segundo argumento ej: int("argumento 1", argumento 2), así puede mostrar la base.
